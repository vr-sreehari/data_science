# %%
# !pip install mysql-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
connection = mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',
    password='admin',
)
print("Connected successfully!")
# Out:
# Connected successfully!

# %%
cursor = connection.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchone()
# Out:
# ('information_schema',)

# %%
cursor.fetchone()
# Out:
# ('mydb',)

# %%
cursor.fetchone()
# Out:
# ('myfirstdb',)

# %%
cursor.fetchone()
# Out:
# ('mysql',)

# %%
cursor.fetchall()
# Out:
# [('mysqldb',), ('performance_schema',), ('sys',)]

# %%
cursor.execute("show databases")
cursor.fetchmany(2)
# Out:
# [('information_schema',), ('mydb',)]

# %%
cursor.fetchmany(2)
# Out:
# [('myfirstdb',), ('mysql',)]

# %%
cursor.fetchmany(2)
# Out:
# [('mysqldb',), ('performance_schema',)]

# %%
cursor.fetchmany(2)
# Out:
# [('sys',)]

# %%
cursor.execute("show databases")
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mydb',),
#  ('myfirstdb',),
#  ('mysql',),
#  ('mysqldb',),
#  ('performance_schema',),
#  ('sys',)]

# %%
cursor.execute("create database mypythondb")

# %%
cursor.close()
connection.close()

# %%
connection = mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',
    password='admin',
    database='mypythondb'
)
print("Connected successfully!")
# Out:
# Connected successfully!

# %%
cursor = connection.cursor()

# %%
cursor.execute("create table students(id int primary key, name varchar(20), age int)")

# %%
cursor.execute("insert into students values(1, 'Alice', 20)")

# %%
connection.commit()

# %%
import os
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
connection2 = mysql.connector.connect(
    host='gateway01.ap-southeast-1.prod.aws.tidbcloud.com',
    port=4000,
    user=os.getenv('tidb_user'),
    password=os.getenv('tidb_password'),
    database='test'
)
print("Connected successfully!")
# Out:
# Connected successfully!

# %%
cursor2 = connection2.cursor()

# %%
cursor2.execute("show tables")
cursor2.fetchall()
# Out:
# []

# %%
cursor2.execute("create table students(id int primary key, name varchar(20), age int)")

# %%
cursor2.execute("insert into students values(1, 'Alice', 20)")
connection2.commit()

# %%
cursor2.execute("select * from students")
cursor2.fetchall()
# Out:
# [(1, 'Alice', 20)]
